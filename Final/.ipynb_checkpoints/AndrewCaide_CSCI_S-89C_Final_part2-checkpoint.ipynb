# %% [markdown]
# ## Name: Andrew Caide
# ### CSCI S-89C Deep Reinforcement Learning
# ### Part II of Final

# %%
import time
import random
import pickle

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from keras import layers
from keras import models
from keras.layers import Dropout
from keras.datasets import mnist

# %% [markdown]
# ## Problem 1 (5 points)

# %% [markdown]
# Consider the optimal selection of a treatment. Suppose that there are 4 types of treatments available. The outcome of each treatment is either 1 (recovery) or 0.
#
# Let's denote the outcome by $R_t$, then $R_t|(A_t=a)$ follows $\text{Bernoulli}(p_a)$ with $a\in\{1,2,3,4\}$ and all $p_a\in [0,1]$, where $A_t$ denotes the action on time step $t=1,2,3,\ldots$.
#
# Assume that $p_1=0.05$, $p_2=0.15$,  $p_3=0.55$, $p_4=0.85$, which are not known to the doctor. This is the 4-armed Bandit Problem with Bernoulli distributions. The rewards $R_t$ are 0's and 1's. Please notice that $P\{R_t=1|A_t=a\}=p_a$. Also, the expectation $E\left[R_t|A_t=a \right]=p_a$.
#
# Develop the Upper-Confidence-Bound Action Selection algorithm for the problem of selecting the best treatment and report the following graphs:
#
# (a) Run the algorithm for $t=1,2,3,\ldots,400$ and plot $R_t$'s v.s. $t$ for one simulation. Use $c=0.15$.
# (b) Run 100 trajectories in (a); and for each time step $t$ plot the average of $R_t$'s from all 100 trajectories at this particular time (please do not average all returns over time - we want to see how the learning progresses over time). Use $c=0.15$.
# (c) Using trajectories you obtained in (b), for each time step $t$, plot the proportion  (out of 100) of times the best action (action $a=4$) was selected by the doctor. Again, use $c=0.15$.
#
# ----
#
# 0. Develop the Upper-Confidence-Bound Action Selection algorithm for the problem of selecting the best treatment.

# %%
class Environment:
    def __init__(self):
        self.time = 1
        self.valid_actions = {1:0.05, 2:0.15, 3:0.55, 4:0.85} 
    
    def get_reward(self, action):
        self.time += 1
        p1 = 1-self.valid_actions[action]
        p2 = self.valid_actions[action]
        return np.random.choice([0, 1],p=[p1, p2])
    
    
class UCB_Agent:
    def __init__(self, c = 0.15):
        self.c = c
        self.Q = np.zeros(4)
        self.t = np.zeros(4)
        self.rewards = []
        self.actions_taken =[]
        self.best_action_taken = []
        self.four_counter = 0

    def step(self, env):
        
        # Test all actions first
        if any(self.t) == 0:
            for action in range(1,5):
                reward = env.get_reward(action)
                
                self.Q[action-1] = reward
                self.t[action-1] += 1
                
                self.actions_taken.append(action)
                self.rewards.append(reward)
                if action == 4:
                    self.four_counter +=1
                self.best_action_taken.append(self.four_counter)
                
        else:
            # UCB Action Selection:
            best_action = np.argmax(self.Q + self.c*np.sqrt(np.log(self.t)/self.t))+1
            reward = env.get_reward(best_action)
            
            self.actions_taken.append(best_action)
            self.rewards.append(reward)
            
            self.Q[best_action-1] = reward
            self.t[best_action-1] += 1
            
            if best_action == 4:
                self.four_counter +=1
            self.best_action_taken.append(self.four_counter)

# %% [markdown]
# ---
# (a) Run the algorithm for $t=1,2,3,\ldots,400$ and plot $R_t$'s v.s. $t$ for one simulation. Use $c=0.15$.

# %%
env = Environment()
agent = UCB_Agent()
for t in range(0,397):
    agent.step(env)
action_rewards = pd.DataFrame({"Actions":agent.actions_taken, "Rewards":agent.rewards})
action_rewards['time'] = action_rewards.index + 1
action_rewards.head(2)
# Out:
#    Actions  Rewards  time
# 0        1        0     1
# 1        2        0     2

# %%
plt.figure(figsize=(16,6))
plt.plot(action_rewards['time'], action_rewards['Rewards'], linestyle='--', 
         marker='o', markersize=4, label='UCB Action Selection Rewards')
plt.xlabel("t")
plt.ylabel("$R_t$")
plt.title('Dependence of historical rewards $R_t$ on $t$ for one simulation')
plt.grid(True)
plt.legend(loc = 'upper right')
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(action_rewards['time'], action_rewards['Actions'], linestyle='--', 
         marker='o', markersize=4, label='UCB Action Selection - Actions Taken')
plt.xlabel("t")
plt.ylabel("$A_t$")
plt.title('Dependence of historical rewards $R_t$ on $t$ for one simulation')
plt.grid(True)
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# (b) Run 100 trajectories in (a); and for each time step $t$ plot the average of $R_t$'s from all 100 trajectories at this particular time (please do not average all returns over time - we want to see how the learning progresses over time). Use $c=0.15$.

# %%
q1_partb = pd.DataFrame()

for i in range(0,101):
    env = Environment()
    agent = UCB_Agent()
    for t in range(0,97):
        agent.step(env)
        
    action_rewards = pd.DataFrame({"Actions":agent.actions_taken, 
                                   "Rewards":agent.rewards,
                                   "Fours":agent.best_action_taken})
    action_rewards['time'] = action_rewards.index + 1
    q1_partb = q1_partb.append(action_rewards)

# %%
average_reward = q1_partb.groupby('time')['Rewards'].mean()
plt.figure(figsize=(16,6))
plt.plot(average_reward.index, average_reward.T)
plt.xlabel("t",fontsize = 25.0)
plt.ylabel("$R_t$",fontsize = 25.0)
plt.title('Dependence of historical rewards $R_t$ on $t$ for 100 simulations',fontsize = 20.0)
plt.show()

# %% [markdown]
# (c) Using trajectories you obtained in (b), for each time step $t$, plot the proportion  (out of 100) of times the best action (action $a=4$) was selected by the doctor. Again, use $c=0.15$.

# %%
average_reward = q1_partb.groupby('time')['Fours'].mean()/100
plt.figure(figsize=(16,6))
plt.plot(average_reward.index, average_reward.T)
plt.xlabel("t",fontsize = 25.0)
plt.ylabel("$N_t(a) = 4$",fontsize = 25.0)
plt.title('Number of times $A=4$ across $t$ for 100 simulations',fontsize = 20.0)
plt.show()

# %% [markdown]
# ## Problem 2 (5 points)

# %% [markdown]
# Consider Environment that has five states: 1, 2, 3, 4, and 5. Possible transitions are: (1) 1->1, 1->2; (2) 2->1, 2->2, 2->3; (3) 3->2, 3->3, 3->4; (4) 4->3, 4->4, 4->5; (5) 5->4, 5->5.
#
# Actions of the Agent are decoded by -1, 0, and +1, which correspond to its intention to move left, stay, and move right, respectively. The Environment, however, does not always respond to these intentions exactly, and there is 10% chance that action 0 will result in moving to the right (if moving to the right is admissible), and -1 action will result in staying - in other words, there is a "west wind." More specifically, the non-zero transition probabilities $p(s^\prime,r|s,a)$ are
#
# $p(s^\prime=1,r=0|s=1,a=0)=0.9, p(s^\prime=2,r=0|s=1,a=0)=0.1$,
# $p(s^\prime=2,r=0|s=1,a=+1)=1$,<br>
#
# $p(s^\prime=1,r=0|s=2,a=-1)=0.9, p(s^\prime=2,r=0|s=2,a=-1)=0.1$,<br>
# $p(s^\prime=2,r=0|s=2,a=0)=0.9,p(s^\prime=3,r=-10|s=2,a=0)=0.1$,<br>
# $p(s^\prime=3,r=-10|s=2,a=+1)=1$,<br>
#
# $p(s^\prime=2,r=0|s=3,a=-1)=0.9,p(s^\prime=3,r=-10|s=3,a=-1)=0.1$,<br>
# $p(s^\prime=3,r=-10|s=3,a=0)=0.9,p(s^\prime=4,r=0|s=3,a=0)=0.1$,<br>
# $p(s^\prime=4,r=0|s=3,a=+1)=1$,<br>
#
# etc.
#
# Further, we assume that whenever the process enters state 3, the Environment generates reward = -10. In all other cases the reward is 0. For example, transition 2->3 will result in reward -10, transition 3->3 will result in reward -10, transition 3->2 will result in reward 0, transition 2->2 will result in reward 0, etc.
#
#
#
# Further, assume that the agent does not know about the wind or what rewards to expect. It chooses to stay in all states, i.e. the policy is
# $\pi(-1|1)=0, \pi(0|1)=1, \pi(+1|1)=0$,<br>
# $\pi(-1|2)=0, \pi(0|2)=1, \pi(+1|2)=0$,<br>
# $\pi(-1|3)=0, \pi(0|3)=1, \pi(+1|3)=0$,<br>
# $\pi(-1|4)=0, \pi(0|4)=1, \pi(+1|4)=0$,<br>
# etc.
#
# Please estimate the state-value function using 2-step Temporal Difference (TD) prediction. Let’s use $\gamma=0.9$ and run the episodes for $T=100$.

# %%
class P2_Environment:
    def __init__(self, S0 = 1):
        self.time = 0
        self.state = S0

    def admissible_actions(self):
        A = list((-1,0,1))
        if self.state == 1: A.remove(-1)
        if self.state == 5: A.remove(1)
        return A

    def get_reward(self, action):
        self.time += 1
        move = action
        if self.state > 1 and move > -1:
            move = np.random.choice([move-1, move],p=[0.1,0.9])
        self.state += move
        if self.state == 3:
            reward = -10
        else:
            reward = 0
        return reward
    
class P2_Agent:
    def __init__(self):
        self.current_reward = 0.0

    def step(self, env):
        action_selected = 0
        reward = env.get_reward(action_selected)            
        self.current_reward = reward

# %%
# Run 1 EP:

class V_2StepTD:
    def __init__(self, S0=1, gamma = 0.9):
        self.S0 = S0
        self.gamma = gamma
        self.V = np.zeros(5)

        # Set env+agent 
        self.env = P2_Environment(S0)
        self.agent = P2_Agent()
    
    def update_V(self):      
        G = 0
        
        agent.step(env)
        r1 = self.agent.current_reward
        S1 = self.env.state
        self.agent.step(self.env)
        r2 = self.agent.current_reward
        v = self.V[self.env.state-1]
        
        self.V[self.S0-1] = r1 + r2*self.gamma + v*self.gamma**2
        
        # Take a step back to S1 (aka S0+t)
        self.env = P2_Environment(S1)
        self.S0 = S1

# %%
def scan_2StepTD(T = 100):
    # We're going to scan states 1-5 100 times each, and take average
    
    results = pd.DataFrame()
    for state0 in range(1,6):
        state_values = pd.DataFrame()
        system = V_2StepTD(state0)
        
        for t in range(0,T):
            system.update_V()
            state_values = state_values.append(pd.DataFrame(system.V).T, ignore_index = True)
        state_values = state_values.mean().T
        results = results.append(state_values, ignore_index = True)
    
    
    return results.sum(axis=1)

# %%
scan_2StepTD()
# Out:
# 0     0.000000
# 1     0.000000
# 2   -59.616173
# 3    -6.798210
# 4     0.000000
# dtype: float64

# %% [markdown]
# ## Problem 3 (5 points)

# %% [markdown]
# In this problem, we consider the optimization of hospital patient flow using the Markov Decision Process. We assume that the hospital can hold 300 patients at most.
#
# Further, we introduce three states as follows:
#
# "Low" if number of patients is in $[0,100)$
# "Medium" if number of patients is in $[101,200)$
# "High" if number of patients is in $[201,300]$
#
# Please notice that this aggregation is an improtant step as it allows one to accuratly estimate the transition probabilities from state to state using the database that tracks journeys of patients through the hospital from arrival to discharge.
#
#
#
# One time step corresponds to one day and the administration of the hospital can select the following actions:
#
# If the hospital has "Low" number of patients, then $a \in \{0\}$, where $0$ indicates that no patient will be released early.
# If the hospital has "Medium" number of patients, then $a \in \{0,1\}$, i.e. besides action $a=0$, only one additional action is admissible, namely $1$. This action corresponds to releasing $10$ patients early.
# If the hospital has "High" number of patients, then $a \in \{0,1,2\}$, i.e. besides action $a=0$, two additional actions, namely $1$ and $2$, are admissible. Action $a=1$ again corresponds to releasing $10$ patients early, while action $2$ indicates releasing $20$ patients early.
#
# <br>
#
# Further, assume that we found the transition probabilities $p(S_{t+1}=s^\prime|S_t=s,A_t=a)$ to be (for a data-driven estimates refer, for instance, to "Markov Decision Process Model for Optimisation of Patient Flow" by Clissold, J. Filar, S. Qin, and D.Ward, 21st International Congress on Modelling and Simulation, Gold Coast, Australia, 29 Nov to 4 Dec 2015):
#
# $p(S_{t+1}=s^\prime|S_t=s,A_t=0)=\begin{bmatrix}
# 0.8 & 0.2 & 0 \\
# 0.25 & 0.7 & 0.05\\
# 0.01 & 0.25 & 0.74\\
# \end{bmatrix}$
#
# Here, we use the Markov Chain convention with $s$ being the row index (in the order from "Low" to "Hight"), and $s^\prime$ being the column index.
# For example, $p(S_{t+1}=\text{"High"}|S_t=\text{"Medium"},A_t=0)=0.05$ and $p(S_{t+1}=\text{"Medium"}|S_t=\text{"Low"},A_t=0)=0.2$.
#
# If, however, the hospital decides to release $10$ patients early, i.e. $A_t=1$, the probability of moving to a "lower" hospital occupancy level are now larger, while the probability of moving to a "higher" state are smaller:
#
# $p(S_{t+1}=s^\prime|S_t=s,A_t=1)=\begin{bmatrix}
# - & - & - \\
# 0.25+0.1 & 0.7-0.09 & 0.05-0.01\\
# 0.01+0.01 & 0.25+0.09 & 0.74-0.1\\
# \end{bmatrix}$
#
# where same $s, s^\prime$ index convention is used. Plase notice that in state $s=\text{"Low"}$ action $A_t=1$ is unavailable resuting in missing probabilities (denoted by "-") in the matrix above. On the other hand, $p(S_{t+1}=\text{"High"}|S_t=\text{"Medium"},A_t=1)=0.05-0.1$, for example.
#
# Finally, if the decision maker selects to reaease $20$ patients early, i.e. $A_t=20$, then
#
# $p(S_{t+1}=s^\prime|S_t=s,A_t=2)=\begin{bmatrix}
# - & - & - \\
# - & - & -\\
# 0.01+0.02 & 0.25+0.18 & 0.74-0.2\\
# \end{bmatrix}.$
#
# <br><br>
#
# The reward $R_{t+1}$ obtained as a result of action $A_t$ is defined as follows:
# $R_{t+1}=\frac{1}{10}\left[\mathbb{1}_{\{S_{t+1}=\text{"Low"}\}}\cdot 49.5+\mathbb{1}_{\{S_{t+1}=\text{"Medium"}\}}\cdot 150.5+\mathbb{1}_{\{S_{t+1}=\text{"High"}\}}\cdot 255.5 + A_t\cdot (-10)\right]+\frac{9}{10}\left[\mathbb{1}_{\{S_{t+1}=\text{"High"}\}}\cdot (-30)\right]$.
#
# Here, the first term $\frac{1}{10}\left[\ldots\right]$ is related to the direct profit of the hospital, while the second term $\frac{9}{10}\left[\ldots\right]$ is associated with the inconvenience of patients, risk of refusal for admission of new patients, and the reputation of the hospital.
#
# <br>
# Using this information, please find the optimal policy for the decision making via Double Q-learning. Use $\gamma=0.9$. Please treat this problem as a continuing task.

# %%
class P3_Environment:
    def __init__(self, S0):
        self.time = 1
        self.state = S0
        self.new_state = 0
        self.trans_probabilities = 0
        self.action = 0
        self.p = 0
        
    def set_state(self, new_state):
        self.state = new_state
        
    
    def set_transition_probabilities(self):
        if self.action == 0:
            self.trans_probabilities = [np.array([.8, .2, 0]),
                                              np.array([.25, 0.7, 0.05]),
                                              np.array([0.01, 0.25, 0.74])][self.state]
        elif self.action == 1:
            self.trans_probabilities = [np.array([0, 0, 0]),
                                              np.array([.25+.1, 0.7-0.09, 0.05-0.01]),
                                              np.array([0.01+0.01, 0.25+0.09, 0.74-0.1])][self.state]
        else:
            self.trans_probabilities = [np.array([0, 0, 0]),
                                              np.array([0, 0, 0]),
                                              np.array([0.01+0.02, 0.25+0.18, 0.74-0.2])][self.state]
            
    def get_reward(self):
        return np.array([1/10*(49.5 + (-10)*self.action),
                        1/10*(150.5 + (-10)*self.action),
                        1/10*(255.5 + (-10)*self.action) + 9/10*(-30)])
        
        
    def evaluate(self, action):
        # With the new action, and the new state
        #   1. get transaction probability based on [action -> state -> newstate]
        #   2. save p
        #   3. get reward
        self.action = action
        self.set_transition_probabilities()
        #print("State: {}, Action: {}".format(self.state, self.action))
        #print("Transition probabilities: {}.".format(self.trans_probabilities))
        
        if sum(self.trans_probabilities) != 0:
            new_state = np.random.choice([0,1,2], p=self.trans_probabilities)
            #print("New state: {}\n---".format(new_state))
            self.state = new_state
            self.p = self.trans_probabilities[new_state]
            return self.get_reward()[new_state]
        
        else:
            return self.get_reward()[self.state]

# %%
class P3_Agent:
    def __init__(self):
        self.current_reward = 0.0
        self.scan = 1
        self.scan_done = False

    def step(self, env, take_action = False, policy = 1):
        if take_action:
            action_selected = take_action
        else:
            action_selected = 0 # Stay put
        
        self.current_reward = env.evaluate(action_selected)

# %%
def get_policy_from_q(q, eps):
    # Get the optimal policy given a specific state-value Q
    # Identify max value, set it as the e-greedy value!
    
    if np.count_nonzero(q == 0) == 1:
        policy = pd.DataFrame(eps/2, index=range(1,2), columns={0,1,2})
        policy.loc[:,q.idxmax(1)] = 1-eps + eps/2
        policy.loc[:,q.idxmin(1)] = 0
        
    elif np.count_nonzero(q == 0) == 2:
        policy = pd.DataFrame(0, index=range(1,2), columns={0,1,2})
        policy.loc[:,q.idxmax(1)] = 1
    else:
        policy = pd.DataFrame(eps/3, index=range(1,2), columns={0,1,2})
        policy.loc[:,q.idxmax(1)] = 1-eps + eps/3
    
    return(policy.values.tolist()[0])

# %%
def double_q(alpha = 0.1, gamma = 0.9, episodes = 200, eps = .3, T = 100):
    # initiate Q1, Q2 for all S and A, such that terminal = 0
    Q1 = pd.DataFrame(1, index=range(0,3), columns={0,1,2})
    Q1.loc[0,1] = 0
    Q1.loc[0,2] = 0
    Q1.loc[1,2] = 0

    Q2 = pd.DataFrame(1, index=range(0,3), columns={0,1,2})
    Q2.loc[0,1] = 0
    Q2.loc[0,2] = 0
    Q2.loc[1,2] = 0
    
    for episode in range(episodes):
        S0 = random.randint(0,2)
            
        env = P3_Environment(S0)
        agent = P3_Agent()
        S = env.state
        t = 0
        while t<T:
            t+=1
            action_vals = Q1+Q2
            #print("Action Value Table: \n{}".format(action_vals))
            Q = action_vals.loc[S]
            
            # Make greedy policy
            policy = get_policy_from_q(Q, eps)
            #print("Policy: {}\n---".format(policy))
            
            A = np.random.choice([0, 1, 2], 1, p=policy)[0] 
            #print("Double-Q policy: {}".format(policy))
            
            # Take action A, observe R, S'
            agent.step(env, take_action = A)
            reward = agent.current_reward    # R
            S1 = env.state                   # S'
            
            # With a 0.5 probability:
            if random.choice([True,False]):
                # Argmax Q1(S',*)
                try:
                    best_q1_action = Q1.loc[S1].idxmax(1)

                    Q1.loc[S,A] = Q1.loc[S,A] +\
                        alpha*(reward +\
                               gamma*Q2.loc[S1,best_q1_action] - Q1.loc[S,A])
                    #print("Updated Q1: \n{}".format(Q1))
                except:
                    print("State: {}, Action: {}, Q1: ".format(S1, A))
                    print(Q1)

            else:
                # Argmax Q2(S',*)
                try:
                    best_q2_action = Q2.loc[S1].idxmax(1)

                    Q2.loc[S,A] = Q2.loc[S,A] +\
                        alpha*(reward +\
                               gamma*Q1.loc[S1,best_q2_action] - Q2.loc[S,A])
                    #print("Updated Q2: \n{}".format(Q2))
                except:
                    print("State: {}, Action: {}, Q2: ".format(S1, A))
                    print(Q2)
                    
            S = S1 # S <- S'

    Q_final = Q1+ Q2
    return Q_final.divide(Q_final.max(axis=1), axis=0)

# %%
dqres = double_q()
print("Action-Value by Actions (columns) x States (rows):\n{}".format(dqres))
print("\n----\n")
print("Optimal actions:\n{}".format(dqres.idxmax(1)))
# Out:
# Action-Value by Actions (columns) x States (rows):
#           0         1    2
# 0  1.000000  0.000000  0.0
# 1  1.000000  0.975555  0.0
# 2  0.890097  0.886018  1.0
#
# ----
#
# Optimal actions:
# 0    0
# 1    0
# 2    2
# dtype: int64

# %% [markdown]
# ## Problem 4 (10 points)

# %% [markdown]
# In this problem we will develop an algorithm for approximating state values using Deep Neural Network (NN). We consider images of size 28x28, which can be treated as vectors of 784 features: ${\bf x}=(x_1,x_2,\ldots,x_{784})^T$.
#
# Please load the observations of features ${\bf x}(S_t)$, $t=0,1,\ldots$ ('images' variable), actions $A_t$, $t=0,1,\ldots$ ('actions' variable), and rewards $R_t$, $t=1,2,\ldots$ from the 'markov_decision_process.pkl' file. Please notice that in each state $s\in \mathcal{S}$, the set of admissible actions is $\mathcal{A}(s)=\{0,1,2\}$. Here, "0" states for no treatment and "1" and "2" are two treatments of different types. We assume that this is a Markov Decision Process, that is, the joint distribution of the next state $S_{t+1}$ and reward $R_{t+1}$ depens on the pair of current state and action $(S_t, A_t)$ only.
#
# These rewards were obtained under uniform policy $\pi$, that is, actions were selected at random from the action space $\mathcal{A}(s)$. Please develop a 1-step TD prediction algorithm with approximation via a Deep NN to evaluate state values $v_\pi(s)$ under this pilicy $\pi$. Please use the vector of fetures ${\bf x}(S_t)$ as an input to the NN. The output of the NN should be the state-values $\hat{v}(S_t,{\bf w})$. Please feel free to use either feedforward fully connected NN or Convolutional NN.
#
# Please
# - train the NN in mini-batches of size 128, that is, the weights ${\bf w}$ will be updated every 128 time steps
# - update the target $R_{t+1}+\gamma\hat{v}(S_{t+1},{\bf w})$ every 1280 time steps only, that is, not the most recent weights should be used to evaluate this taget  - this usually guarantees a better stability of the algorithm
#
# Once the training is finished, please pick 24 images at random and display them together with the estimated state values in the titles.

# %%
with open('markov_decision_process.pkl', 'rb') as f:
    images, actions, rewards = pickle.load(f)
    
# This cheat switches the problem on its head; we start looking for the worst action
#rewards = np.abs(rewards)

k = 0
fig = plt.figure(figsize=(15,8))
for t in range(18):
    k += 1
    plt.subplot(3,6,k)
    plt.tight_layout()
    plt.imshow(images[t], cmap='gray', interpolation='none')
    plt.title("$A_{" + str(t) + "}=$"+str(actions[t])+"\n$R_{" + str(t+1) + "}=$"+str(round(rewards[t],2)))
    plt.xticks([])
    plt.yticks([])
    
actions_1hot = pd.get_dummies(actions)
ims = images.reshape(-1, 784).astype('float32')
ims /= 255
print("Image shape: {}.".format(ims.shape))
X = np.concatenate((ims, np.array(actions_1hot)), axis = 1)
print("Image shape with actions: {}.".format(X.shape))
# --- 
X0 = X.copy()
X1 = X.copy()
X2 = X.copy()
X0[:,784:787] = 0
X0[:,784] = 1
X1[:,784:787] = 0
X1[:,785] = 1
X2[:,784:787] = 0
X2[:,786] = 1
# Out:
# Image shape: (50000, 784).
# Image shape with actions: (50000, 787).

# %%
set(actions)
# Out:
# {0, 1, 2}

# %% [markdown]
# ---
#
# - train the NN in mini-batches of size 128, that is, the weights ${\bf w}$ will be updated every 128 time steps
# - update the target $R_{t+1}+\gamma\hat{v}(S_{t+1},{\bf w})$ every 1280 time steps only, that is, not the most recent weights should be used to evaluate this taget  - this usually guarantees a better stability of the algorithm

# %%
# NN 
# Hyper-parameters
BATCH_SIZE = 128
INPUT_SHAPE = (787,)
KERNEL_SIZE = 4
FILTER_SIZE = 4 
# ---------

model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=INPUT_SHAPE))                          
model.add(Dropout(0.2))
model.add(layers.Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Dense(1, activation='relu'))

model.compile(loss='mse',  metrics=['mse'], optimizer='adam')

# ----

T = len(rewards)
gamma = 0.9
chunk_size = 1280
n_chunks = int(T/chunk_size)
V0 = 0
alpha = 0.1

for k in range(n_chunks):
    time_range = np.arange(chunk_size*k, chunk_size*(k+1))
    print("Current time: {}".format(time_range[0]))
    
    q_hat0 = model.predict(X0[time_range+1])
    q_hat1 = model.predict(X1[time_range+1])
    q_hat2 = model.predict(X2[time_range+1])
    
    # Hmm
    q_hatOpt = np.min(np.concatenate((q_hat0,q_hat1,q_hat2),axis=1),axis=1)
    target = -np.array(rewards)[time_range] + gamma*q_hatOpt
    # 1-Step TD
    V1 = V0 + alpha*(target - V0)
    V0 = V1
    print(V1)
    history = model.fit(X[time_range], target, batch_size = 128, epochs=10)#, verbose = 1)
    
model.predict(X).max()
# Out:
# Current time: 0
# [0.1110485  0.05858445 0.58316943 ... 0.55339347 0.5218846  0.57691136]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 5.0414 - mse: 5.0414
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5603 - mse: 1.5603
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0490 - mse: 1.0490
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7963 - mse: 0.7963
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6198 - mse: 0.6198
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5353 - mse: 0.5353
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4553 - mse: 0.4553
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4015 - mse: 0.4015
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3198 - mse: 0.3198
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2966 - mse: 0.2966
# Current time: 1280
# [0.58567032 0.50099957 1.05206856 ... 1.31261032 0.98439468 0.74421827]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 7.6556 - mse: 7.6556
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 4.2282 - mse: 4.2282
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 3.1378 - mse: 3.1378
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 2.2468 - mse: 2.2468
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7491 - mse: 1.7491
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2749 - mse: 1.2749
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1828 - mse: 1.1828
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9638 - mse: 0.9638
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9533 - mse: 0.9533
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8459 - mse: 0.8459
# Current time: 2560
# [0.99891266 1.1681003  1.32043622 ... 1.72245843 1.27957792 1.29464095]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7957 - mse: 1.7957
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3950 - mse: 1.3950
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0982 - mse: 1.0982
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0423 - mse: 1.0423
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9292 - mse: 0.9292
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7403 - mse: 0.7403
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7604 - mse: 0.7604
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6752 - mse: 0.6752
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6174 - mse: 0.6174
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5916 - mse: 0.5916
# Current time: 3840
# [1.04390751 1.24244633 1.94736467 ... 2.72710842 2.24682981 2.21875984]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9439 - mse: 1.9439
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7016 - mse: 1.7016
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3495 - mse: 1.3495
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0880 - mse: 1.0880
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0652 - mse: 1.0652
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0278 - mse: 1.0278
# Epoch 7/10
# 10/10 [==============================] - 0s 1000us/step - loss: 0.8761 - mse: 0.8761
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8631 - mse: 0.8631
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7296 - mse: 0.7296
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8093 - mse: 0.8093
# Current time: 5120
# [1.67162084 1.81994697 2.40305368 ... 3.43956301 3.17541771 3.16295456]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8302 - mse: 1.8302
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3416 - mse: 1.3416
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0732 - mse: 1.0732
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0247 - mse: 1.0247
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8803 - mse: 0.8803
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7769 - mse: 0.7769
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7515 - mse: 0.7515
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7006 - mse: 0.7006
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6839 - mse: 0.6839
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6374 - mse: 0.6374
# Current time: 6400
# [2.2837294  1.81934071 2.57482292 ... 3.76111035 4.05526213 3.64727475]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 2.1052 - mse: 2.1052
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8521 - mse: 1.8521
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6212 - mse: 1.6212
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4295 - mse: 1.4295
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2654 - mse: 1.2654
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9961 - mse: 0.9961
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9631 - mse: 0.9631
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8267 - mse: 0.8267
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7725 - mse: 0.7725
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7393 - mse: 0.7393
# Current time: 7680
# [2.68778058 2.65592255 3.32382863 ... 4.62966931 5.0121788  4.06325219]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9259 - mse: 1.9259
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5200 - mse: 1.5200
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3790 - mse: 1.3790
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1723 - mse: 1.1723
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1088 - mse: 1.1088
# Epoch 6/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.8584 - mse: 0.8584
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7436 - mse: 0.7436
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7512 - mse: 0.7512
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7202 - mse: 0.7202
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6429 - mse: 0.6429
# Current time: 8960
# [2.80101369 3.15570939 4.30275892 ... 4.64653164 5.2362175  4.91530838]
# Epoch 1/10
#  1/10 [==>...........................] - ETA: 0s - loss: 1.7308 - mse: 1.7308WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6735 - mse: 1.6735
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3468 - mse: 1.3468
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1044 - mse: 1.1044
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0050 - mse: 1.0050
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8705 - mse: 0.8705
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7989 - mse: 0.7989
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7548 - mse: 0.7548
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7372 - mse: 0.7372
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7748 - mse: 0.7748
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8095 - mse: 0.8095
# Current time: 10240
# [3.90469162 4.08190252 5.14481278 ... 4.95001188 5.77139739 5.2248901 ]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 2.0271 - mse: 2.0271
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6422 - mse: 1.6422
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3463 - mse: 1.3463
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1105 - mse: 1.1105
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9559 - mse: 0.9559
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9453 - mse: 0.9453
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9403 - mse: 0.9403
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8955 - mse: 0.8955
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8233 - mse: 0.8233
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7266 - mse: 0.7266
# Current time: 11520
# [4.85478181 4.97374343 5.91070268 ... 4.8529029  5.96648842 5.86676581]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8228 - mse: 1.8228
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4705 - mse: 1.4705
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5261 - mse: 1.5261
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1950 - mse: 1.1950
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0635 - mse: 1.0635
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9516 - mse: 0.9516
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9320 - mse: 0.9320
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7975 - mse: 0.7975
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7724 - mse: 0.7724
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8345 - mse: 0.8345
# Current time: 12800
# [5.71655575 5.30952707 6.14575861 ... 4.78780009 6.14148097 6.27065255]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6223 - mse: 1.6223
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2653 - mse: 1.2653
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0657 - mse: 1.0657
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0052 - mse: 1.0052
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0315 - mse: 1.0315
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8778 - mse: 0.8778
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7564 - mse: 0.7564
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7005 - mse: 0.7005
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7220 - mse: 0.7220
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7083 - mse: 0.7083
# Current time: 14080
# [5.95772328 6.04995886 6.82125437 ... 5.19425939 6.88674988 6.91697873]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5841 - mse: 1.5841
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3348 - mse: 1.3348
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1142 - mse: 1.1142
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1124 - mse: 1.1124
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1397 - mse: 1.1397
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9374 - mse: 0.9374
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8218 - mse: 0.8218
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7533 - mse: 0.7533
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7613 - mse: 0.7613
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7481 - mse: 0.7481
# Current time: 15360
# [6.68413475 6.74180898 7.17901496 ... 5.91382958 7.5493146  7.50224768]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5314 - mse: 1.5314
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3381 - mse: 1.3381
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1635 - mse: 1.1635
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0010 - mse: 1.0010
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0143 - mse: 1.0143
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7635 - mse: 0.7635
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7315 - mse: 0.7315
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6943 - mse: 0.6943
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6940 - mse: 0.6940
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6648 - mse: 0.6648
# Current time: 16640
# [7.29147401 7.47835247 7.78001484 ... 6.56784724 8.08715532 8.08582553]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6139 - mse: 1.6139
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2356 - mse: 1.2356
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1036 - mse: 1.1036
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9491 - mse: 0.9491
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8346 - mse: 0.8346
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8344 - mse: 0.8344
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8564 - mse: 0.8564
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7496 - mse: 0.7496
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7278 - mse: 0.7278
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6548 - mse: 0.6548
# Current time: 17920
# [7.98813521 8.00245045 8.33884622 ... 6.50792537 7.91147037 7.85198871]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7680 - mse: 1.7680
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4828 - mse: 1.4828
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2293 - mse: 1.2293
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1605 - mse: 1.1605
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0440 - mse: 1.0440
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9957 - mse: 0.9957
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0004 - mse: 1.0004
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8728 - mse: 0.8728
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8846 - mse: 0.8846
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7541 - mse: 0.7541
# Current time: 19200
# [7.8016525  7.92514721 8.16935466 ... 6.69667045 8.40978238 8.45669164]
# Epoch 1/10
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4283 - mse: 1.4283
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3074 - mse: 1.3074
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0003 - mse: 1.0003
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8722 - mse: 0.8722
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8282 - mse: 0.8282
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7488 - mse: 0.7488
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8169 - mse: 0.8169
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7129 - mse: 0.7129
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6931 - mse: 0.6931
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6725 - mse: 0.6725
# Current time: 20480
# [8.3145932  7.95284649 8.22629929 ... 6.61744108 8.05684339 8.51342077]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.6674 - mse: 1.6674
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3381 - mse: 1.3381
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1019 - mse: 1.1019
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9854 - mse: 0.9854
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9608 - mse: 0.9608
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8272 - mse: 0.8272
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8780 - mse: 0.8780
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7877 - mse: 0.7877
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7684 - mse: 0.7684
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7078 - mse: 0.7078
# Current time: 21760
# [8.50321084 7.964634   8.78891766 ... 6.47149058 8.12680383 9.15001344]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3273 - mse: 1.3273
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0754 - mse: 1.0754
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9476 - mse: 0.9476
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8055 - mse: 0.8055
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8467 - mse: 0.8467
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7543 - mse: 0.7543
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6640 - mse: 0.6640
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6478 - mse: 0.6478
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6451 - mse: 0.6451
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6400 - mse: 0.6400
# Current time: 23040
# [9.02753622 8.56493095 8.79415316 ... 6.4766874  7.92015951 8.81161383]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2711 - mse: 1.2711
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0875 - mse: 1.0875
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0150 - mse: 1.0150
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7940 - mse: 0.7940
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7094 - mse: 0.7094
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6570 - mse: 0.6570
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6600 - mse: 0.6600
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6829 - mse: 0.6829
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6192 - mse: 0.6192
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5749 - mse: 0.5749
# Current time: 24320
# [8.68530212 8.2565059  8.51824537 ... 7.24654498 8.49992555 9.33118468]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3171 - mse: 1.3171
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0038 - mse: 1.0038
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8239 - mse: 0.8239
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8200 - mse: 0.8200
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7590 - mse: 0.7590
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7098 - mse: 0.7098
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6547 - mse: 0.6547
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6716 - mse: 0.6716
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6245 - mse: 0.6245
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5783 - mse: 0.5783
# Current time: 25600
# [9.21662456 8.70413421 8.70660385 ... 7.86637512 9.01265963 9.42345553]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1853 - mse: 1.1853
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1480 - mse: 1.1480
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1156 - mse: 1.1156
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8858 - mse: 0.8858
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8554 - mse: 0.8554
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7110 - mse: 0.7110
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7045 - mse: 0.7045
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6408 - mse: 0.6408
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6307 - mse: 0.6307
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6168 - mse: 0.6168
# Current time: 26880
# [9.14801911 9.3014371  8.84550055 ... 8.54062447 9.59657156 9.84298515]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2891 - mse: 1.2891
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0343 - mse: 1.0343
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9406 - mse: 0.9406
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8408 - mse: 0.8408
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8163 - mse: 0.8163
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8208 - mse: 0.8208
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7178 - mse: 0.7178
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6922 - mse: 0.6922
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6369 - mse: 0.6369
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6164 - mse: 0.6164
# Current time: 28160
# [ 9.61748356  9.29327071  8.87144129 ...  8.62144552  9.46183124
#  10.29248604]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2624 - mse: 1.2624
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0130 - mse: 1.0130
# Epoch 3/10
# 10/10 [==============================] - ETA: 0s - loss: 0.8787 - mse: 0.878 - 0s 1ms/step - loss: 0.8345 - mse: 0.8345
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7555 - mse: 0.7555
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7323 - mse: 0.7323
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6549 - mse: 0.6549
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6322 - mse: 0.6322
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5935 - mse: 0.5935
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6505 - mse: 0.6505
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6084 - mse: 0.6084
# Current time: 29440
# [ 9.7822748   9.34280344  9.36995177 ...  8.76856402  9.53598036
#  10.69219538]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.3720 - mse: 1.3720
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1558 - mse: 1.1558
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9305 - mse: 0.9305
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8214 - mse: 0.8214
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7936 - mse: 0.7936
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6728 - mse: 0.6728
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7607 - mse: 0.7607
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6691 - mse: 0.6691
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7370 - mse: 0.7370
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6432 - mse: 0.6432
# Current time: 30720
# [ 9.80601365  9.28602001  9.32345675 ...  8.76953069  9.59591075
#  10.26905762]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2892 - mse: 1.2892
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9654 - mse: 0.9654
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8356 - mse: 0.8356
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7204 - mse: 0.7204
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7343 - mse: 0.7343
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6681 - mse: 0.6681
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5954 - mse: 0.5954
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6248 - mse: 0.6248
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5654 - mse: 0.5654
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5461 - mse: 0.5461
# Current time: 32000
# [ 9.73657094  9.42245026  8.89258641 ...  9.30340218 10.14448149
#  10.74268755]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1211 - mse: 1.1211
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9829 - mse: 0.9829
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8382 - mse: 0.8382
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8260 - mse: 0.8260
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6953 - mse: 0.6953
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6653 - mse: 0.6653
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6905 - mse: 0.6905
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6068 - mse: 0.6068
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6074 - mse: 0.6074
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5782 - mse: 0.5782
# Current time: 33280
# [10.25208915  9.45577125  8.72010429 ...  9.28822962 10.0722567
#  11.14342938]
# Epoch 1/10
#  1/10 [==>...........................] - ETA: 0s - loss: 1.0502 - mse: 1.0502WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1617 - mse: 1.1617
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9140 - mse: 0.9140
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8323 - mse: 0.8323
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8577 - mse: 0.8577
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8023 - mse: 0.8023
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7306 - mse: 0.7306
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6334 - mse: 0.6334
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5916 - mse: 0.5916
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5516 - mse: 0.5516
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5528 - mse: 0.5528
# Current time: 34560
# [10.73494327 10.00902015  8.84196231 ...  9.53251934  9.64176948
#  10.98429093]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0989 - mse: 1.0989
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9658 - mse: 0.9658
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8808 - mse: 0.8808
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8066 - mse: 0.8066
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6926 - mse: 0.6926
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6051 - mse: 0.6051
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6802 - mse: 0.6802
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6231 - mse: 0.6231
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5548 - mse: 0.5548
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5632 - mse: 0.5632
# Current time: 35840
# [11.08331447 10.42867163  8.98794568 ...  9.89960253 10.04657002
#  11.36989849]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1597 - mse: 1.1597
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9392 - mse: 0.9392
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8566 - mse: 0.8566
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7741 - mse: 0.7741
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6949 - mse: 0.6949
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6513 - mse: 0.6513
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6692 - mse: 0.6692
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6236 - mse: 0.6236
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5595 - mse: 0.5595
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5881 - mse: 0.5881
# Current time: 37120
# [11.09730562 10.33605433  9.52250472 ...  9.85929161 10.05828725
#  10.78240972]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0714 - mse: 1.0714
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9130 - mse: 0.9130
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8254 - mse: 0.8254
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7484 - mse: 0.7484
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7479 - mse: 0.7479
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6860 - mse: 0.6860
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7138 - mse: 0.7138
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5954 - mse: 0.5954
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5679 - mse: 0.5679
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5557 - mse: 0.5557
# Current time: 38400
# [10.58038217 10.01707257  9.36669249 ...  9.54816675  9.7582014
#  10.38557953]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0180 - mse: 1.0180
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8426 - mse: 0.8426
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7184 - mse: 0.7184
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6189 - mse: 0.6189
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6872 - mse: 0.6872
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6094 - mse: 0.6094
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5484 - mse: 0.5484
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4907 - mse: 0.4907
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5047 - mse: 0.5047
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5165 - mse: 0.5165
# Current time: 39680
# [10.35040585  9.69131379  9.3704576  ... 10.04001589 10.21084933
#  10.78125881]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9524 - mse: 0.9524
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7697 - mse: 0.7697
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6720 - mse: 0.6720
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5916 - mse: 0.5916
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5595 - mse: 0.5595
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5594 - mse: 0.5594
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5363 - mse: 0.5363
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4828 - mse: 0.4828
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4756 - mse: 0.4756
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4689 - mse: 0.4689
# Current time: 40960
# [10.31587017  9.66104645  9.56659349 ...  9.97592871 10.6154865
#  11.05516462]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9595 - mse: 0.9595
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8590 - mse: 0.8590
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7121 - mse: 0.7121
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6088 - mse: 0.6088
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5699 - mse: 0.5699
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5802 - mse: 0.5802
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5675 - mse: 0.5675
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5335 - mse: 0.5335
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5917 - mse: 0.5917
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5458 - mse: 0.5458
# Current time: 42240
# [10.80951494 10.09119034 10.06222648 ...  9.57821215 10.29599855
#  10.59153142]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0411 - mse: 1.0411
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8608 - mse: 0.8608
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7097 - mse: 0.7097
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6477 - mse: 0.6477
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6066 - mse: 0.6066
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5728 - mse: 0.5728
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5349 - mse: 0.5349
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5157 - mse: 0.5157
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5985 - mse: 0.5985
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5482 - mse: 0.5482
# Current time: 43520
# [10.70826057 10.56729074 10.07258041 ...  9.76786423 10.0167038
#  10.0917056 ]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1074 - mse: 1.1074
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9028 - mse: 0.9028
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7437 - mse: 0.7437
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6939 - mse: 0.6939
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6392 - mse: 0.6392
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6186 - mse: 0.6186
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5781 - mse: 0.5781
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5238 - mse: 0.5238
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4934 - mse: 0.4934
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5199 - mse: 0.5199
# Current time: 44800
# [10.30080968 10.45386058 10.50569023 ...  9.76083479 10.50721212
#  10.52945103]
# Epoch 1/10
#  1/10 [==>...........................] - ETA: 0s - loss: 1.0774 - mse: 1.0774WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9074 - mse: 0.9074
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8133 - mse: 0.8133
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6647 - mse: 0.6647
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6102 - mse: 0.6102
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6428 - mse: 0.6428
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5724 - mse: 0.5724
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5540 - mse: 0.5540
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4963 - mse: 0.4963
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4844 - mse: 0.4844
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4678 - mse: 0.4678
# Current time: 46080
# [10.39118708 10.08090151 10.6619238  ...  9.8340044  10.92185562
#  10.97892045]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9195 - mse: 0.9195
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7806 - mse: 0.7806
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6457 - mse: 0.6457
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6867 - mse: 0.6867
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6052 - mse: 0.6052
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5820 - mse: 0.5820
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5147 - mse: 0.5147
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5290 - mse: 0.5290
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4516 - mse: 0.4516
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4904 - mse: 0.4904
# Current time: 47360
# [10.86466585 10.52678548 11.04966804 ... 10.27990026 11.35763214
#  10.93610202]
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0800 - mse: 1.0800
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9681 - mse: 0.9681
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7532 - mse: 0.7532
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6744 - mse: 0.6744
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5870 - mse: 0.5870
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5381 - mse: 0.5381
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4573 - mse: 0.4573
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5138 - mse: 0.5138
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4702 - mse: 0.4702
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4650 - mse: 0.4650
# Current time: 48640
# [10.75063932 10.70958063 10.50204863 ... 10.58234483 10.86155194
#  10.82229948]
# Epoch 1/10
#  1/10 [==>...........................] - ETA: 0s - loss: 0.7105 - mse: 0.7105WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8294 - mse: 0.8294
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6868 - mse: 0.6868
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5900 - mse: 0.5900
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5732 - mse: 0.5732
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5537 - mse: 0.5537
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5458 - mse: 0.5458
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4882 - mse: 0.4882
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4929 - mse: 0.4929
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5242 - mse: 0.5242
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4740 - mse: 0.4740
# 16.974838

# %%
# Predict!
q_hat0 = model.predict(X0)
q_hat1 = model.predict(X1)
q_hat2 = model.predict(X2)
AOpt = np.argmin(np.concatenate((q_hat0,q_hat1,q_hat2),axis=1),axis=1)
AOpt.shape
AOpt
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
k = 0
fig = plt.figure(figsize=(15,2.5*13))
fig.suptitle('Test Results',y=1.014,size=16)
for t in range(49919,49919+6*13):
    k += 1
    plt.subplot(13,6,k)
    plt.tight_layout()
    plt.imshow(images[t], cmap='gray', interpolation='none')
    plt.title("$A_{"+str(t)+"}=$"+str(actions[t])+"\n$R_{"+str(t+1)+"}=$"+str(round(rewards[t],2))+"\n$A_{opt}=$"+str(AOpt[t]))
    plt.xticks([])
    plt.yticks([])
    
plt.show()

# %%
# - End
# Thanks for the class - have a great remainder of your summer!
# Andrew Caide
