# %% [markdown]
# ## Name: Andrew Caide
#
# ### CSCI S-89C Deep Reinforcement Learning
# ### Part II of Assignment 11

# %% [markdown]
# # Preface
#
# ## DELETED TO SAVE SPACE

# %%
from keras.datasets import mnist
from matplotlib import pyplot as plt 
import numpy as np
import pandas as pd
import time
import pickle

from keras import layers
from keras import models
from keras.layers import Dropout

# %% [markdown]
# # Problem 1 (20 points)

# %% [markdown]
# In this problem we will develop a Q-learning algorithm for selecting the best treatment based on "medical" images. Each 128x128 image is a vector of 784 features: ${\bf x}=(x_1,x_2,\ldots,x_{784})^T$.

# %% [markdown]
# ---
#
# 1. Please load the observations of features ${\bf x}(S_t)$, $t=0,1,\ldots$ ('images' variable), actions $A_t$, $t=0,1,\ldots$ ('actions' variable), and rewards $R_t$, $t=1,2,\ldots$ from the 'markov_decision_process.pkl' file.
#
# **NOTE:** Please notice that in each state $s\in \mathcal{S}$, the set of admissible actions is $\mathcal{A}(s)=\{0,1,2\}$. Here, "0" states for no treatment and "1" and "2" are two treatments of different types. We assume that this is a Markov Decision Process, that is, the joint distribution of the next state $S_{t+1}$ and reward $R_{t+1}$ depens on the pair of current state and action $(S_t, A_t)$ only.

# %%
with open('markov_decision_process.pkl', 'rb') as f:
    images, actions, rewards = pickle.load(f)
    
    
k = 0
fig = plt.figure(figsize=(15,8))
for t in range(18):
    k += 1
    plt.subplot(3,6,k)
    plt.tight_layout()
    plt.imshow(images[t], cmap='gray', interpolation='none')
    plt.title("$A_{" + str(t) + "}=$"+str(actions[t])+"\n$R_{" + str(t+1) + "}=$"+str(round(rewards[t],2)))
    plt.xticks([])
    plt.yticks([])
    
#plt.show()

# %%
actions_1hot = pd.get_dummies(actions)
ims = images.reshape(-1, 784).astype('float32')
ims /= 255
print("Image shape: {}.".format(ims.shape))


X = np.concatenate((ims, np.array(actions_1hot)), axis = 1)
print("Input shape {}".format(X.shape))
# Out:
# Image shape: (50000, 784).
# Input shape (50000, 787)

# %%
X_A0 = X.copy()
X_A1 = X.copy()
X_A2 = X.copy()
# ---

X_A0[:,784:787] = 0
X_A1[:,784:787] = 0
X_A2[:,784:787] = 0

X_A0[:,784] = 1
X_A1[:,785] = 1
X_A2[:,786] = 1

# %% [markdown]
# ---
# 2. Develop a Q-learning algorithm with approximation via a Deep Neural Network (NN).
# a. Use the vector of fetures ${\bf x}(S_t)$ and representations of actions ${\bf y}(A_t)$ (one-hot encodings) as an input to the NN. The output of the NN should be the corresponding action-value $\hat{q}(S_t,A_t,{\bf w})$.
# b. Feel free to use either feedforward fully connected NN or Convolutional NN.

# %%
#Hyper-parameters
BATCH_SIZE = 128
INPUT_SHAPE = (787,)
KERNEL_SIZE = 4
FILTER_SIZE = 4 
# ---------

model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=INPUT_SHAPE))                          
model.add(Dropout(0.2))
model.add(layers.Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Dense(1, activation='relu'))

model.compile(loss='mse',  metrics=['mse'], optimizer='adam')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               403456
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 666,625
# Trainable params: 666,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
T = len(rewards)
gamma = 0.9
chunk_size = 1280
n_chunks = int(T/chunk_size)


for k in range(n_chunks):
    time_range = np.arange(chunk_size*k, chunk_size*(k+1))
    print("Current time: {}".format(time_range[0]))
    
    q_A0 = model.predict(X_A0[time_range+1])
    q_A1 = model.predict(X_A1[time_range+1])
    q_A2 = model.predict(X_A2[time_range+1])
    
    Q = np.min(np.concatenate((q_A0, q_A1, q_A2), axis=1), axis=1)
    target = -np.array(rewards)[time_range] + gamma*Q
    
    history = model.fit(X[time_range], target, batch_size = 128, epochs=10, verbose = 1)
# Out:
# Current time: 0
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 5.0359 - mse: 5.0359
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4440 - mse: 1.4440
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9606 - mse: 0.9606
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7428 - mse: 0.7428
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5335 - mse: 0.5335
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4348 - mse: 0.4348
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3260 - mse: 0.3260
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2981 - mse: 0.2981
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2447 - mse: 0.2447
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2537 - mse: 0.2537
# Current time: 1280
# Epoch 1/10
#  1/10 [==>...........................] - ETA: 0s - loss: 11.5415 - mse: 11.5415WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 10/10 [==============================] - 0s 1ms/step - loss: 7.5288 - mse: 7.5288
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 4.5079 - mse: 4.5079
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 3.5186 - mse: 3.5186
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 2.4054 - mse: 2.4054
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8204 - mse: 1.8204
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4638 - mse: 1.4638
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2912 - mse: 1.2912
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0877 - mse: 1.0877
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9358 - mse: 0.9358
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8609 - mse: 0.8609
# Current time: 2560
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 2.2236 - mse: 2.2236
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7473 - mse: 1.7473
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5621 - mse: 1.5621
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4341 - mse: 1.4341
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1951 - mse: 1.1951
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0161 - mse: 1.0161
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8993 - mse: 0.8993
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8027 - mse: 0.8027
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7068 - mse: 0.7068
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6493 - mse: 0.6493
# Current time: 3840
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9770 - mse: 1.9770
# Epoch 2/10
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3869 - mse: 1.3869
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1404 - mse: 1.1404
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9955 - mse: 0.9955
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9150 - mse: 0.9150
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7642 - mse: 0.7642
# Epoch 7/10
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7541 - mse: 0.7541
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7235 - mse: 0.7235
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6932 - mse: 0.6932
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6512 - mse: 0.6512
# Current time: 5120
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7768 - mse: 1.7768
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4563 - mse: 1.4563
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4509 - mse: 1.4509
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1167 - mse: 1.1167
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9333 - mse: 0.9333
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8676 - mse: 0.8676
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9489 - mse: 0.9489
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7931 - mse: 0.7931
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7060 - mse: 0.7060
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6814 - mse: 0.6814
# Current time: 6400
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9595 - mse: 1.9595
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4634 - mse: 1.4634
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2436 - mse: 1.2436
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1287 - mse: 1.1287
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0315 - mse: 1.0315
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0482 - mse: 1.0482
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8972 - mse: 0.8972
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7548 - mse: 0.7548
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7254 - mse: 0.7254
# Current time: 7680
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7484 - mse: 1.7484
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2546 - mse: 1.2546
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2835 - mse: 1.2835
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2966 - mse: 1.2966
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0199 - mse: 1.0199
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8877 - mse: 0.8877
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8814 - mse: 0.8814
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8084 - mse: 0.8084
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7664 - mse: 0.7664
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.6365 - mse: 0.6365
# Current time: 8960
# Epoch 1/10
#  1/10 [==>...........................] - ETA: 0s - loss: 2.1576 - mse: 2.1576WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8351 - mse: 1.8351
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5008 - mse: 1.5008
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4329 - mse: 1.4329
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1091 - mse: 1.1091
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9463 - mse: 0.9463
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8587 - mse: 0.8587
# Epoch 7/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7632 - mse: 0.7632
# Epoch 8/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7228 - mse: 0.7228
# Epoch 9/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.8123 - mse: 0.8123
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7702 - mse: 0.7702
# Current time: 10240
# Epoch 1/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.7037 - mse: 1.7037
# Epoch 2/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.4562 - mse: 1.4562
# Epoch 3/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.1883 - mse: 1.1883
# Epoch 4/10
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0559 - mse: 1.0559
# Epoch 5/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9355 - mse: 0.9355
# Epoch 6/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.
10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4650 - mse: 0.4650
# Epoch 10/10
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4900 - mse: 0.4900

# %%
q_opt_a0 = model.predict(X_A0)
q_opt_a1 = model.predict(X_A1)
q_opt_a2 = model.predict(X_A2)

# %%
optimal_action = np.argmin(np.concatenate((q_opt_a0, q_opt_a1, q_opt_a2), axis=1), axis=1)
optimal_action.shape
# Out:
# (50000,)

# %% [markdown]
# ---
# 3. Train the NN in mini-batches of size 128, that is, the weights ${\bf w}$ will be updated every 128 time steps
# a. Update the target $R_{t+1}+\gamma \max_{ a}\hat{q}(S_{t+1},a,{\bf w})$ every 1280 time steps only, that is, not the most recent weights should be used to evaluate this taget  - this usually guarantees a better stability of the algorithm.
# b. Once the training is finished, please pick 18 images at random and display them together with optimal actions in the titles.

# %%
k = 0

fig = plt.figure(figsize = (15, 2.5*13))
fig.suptitle('Test Results', y = 1.014, size = 16)


for t in range(39483, 39483+6*13):
    k += 1
    plt.subplot(13, 6, k)
    plt.tight_layout()
    plt.imshow(images[t], cmap= 'gray', interpolation = 'none')
    
    A = actions[t]
    R = round(rewards[t], 1)
    opt_A = round(optimal_action[t],0)
    
    plt.title("$A_{{{}}}=${} \n$R_{{{}}}=${} \n$A_{{opt,{}}}=${}".format(
    t, A, t, R, t, opt_A))

plt.show()

# %% [markdown]
# ----
# ---
# ---
#
# ### Convolutional NN

# %%
# Attempt was made.


# Hyper-parameters
BATCH_SIZE = 128
INPUT_SHAPE = (28,28,)
KERNEL_SIZE = 4
FILTER_SIZE = 4 
# ---------

model = models.Sequential()
model.add(layers.Conv2D(FILTER_SIZE, 
                        KERNEL_SIZE, 
                        activation = 'relu', 
                        input_shape = INPUT_SHAPE))

model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(4, (5, 5), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(3, activation = 'relu'))
model.add(layers.Dense(1, activation = 'sigmoid'))
          
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a2951e47f352> in <module>
#      13                         KERNEL_SIZE,
#      14                         activation = 'relu',
# ---> 15                         input_shape = INPUT_SHAPE))
#      16
#      17 model.add(layers.MaxPooling2D((2,2)))
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1090       # TODO(reedwm): We should assert input compatibility after the inputs
#    1091       # are casted, not before.
# -> 1092       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1093       graph = backend.get_graph()
#    1094       # Use `self._name_scope()` to avoid auto-incrementing the name.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     194                          ', found ndim=' + str(ndim) +
#     195                          '. Full shape received: ' +
# --> 196                          str(x.shape.as_list()))
#     197     # Check dtype.
#     198     if spec.dtype is not None:
#
# ValueError: Input 0 of layer conv2d is incompatible with the layer: : expected min_ndim=4, found ndim=2. Full shape received: [None, 787]

# %%
for k in range(2):#n_chunks):
    # images, actions, rewards
    
    times = np.arange(chunk_size*k, chunk_size*(k+1))
    print("\nCurrent time t = {}".format(times[0]))
    print(images[times].shape)
    q = model.predict(np.array((images[times], np.array(actions)[times])))
    print(q)
    #q1 = model.predict((images[times+1]))
    #q_opt= np.max(np.concatenate((q1), axis=1), axis=1)
    #target= np.array(rewards)[times] + gamma*q_opt
    
    
    #history = model.fit(images[times], target, batch_size = BATCH_SIZE, epochs = 2, verbose=1)
